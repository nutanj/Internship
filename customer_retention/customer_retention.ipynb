# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel(r'C:\Users\JAYASHREE\Downloads\Customer_retention_dataset\customer_retention_dataset.xlsx')
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(3)
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# 1                              Above 4 years
# 2                                  3-4 years
#
#   6 How many times you have made an online purchase in the past 1 year?  \
# 0                                        31-40 times
# 1                                 41 times and above
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# 1Gender of respondent
# 2 How old are you?
# 3 Which city do you shop online from?
# 4 What is the Pin Code of where you shop online from?
# 5 Since How Long You are Shopping Online ?
# 6 How many times you have made an online purchase in the past 1 year?
# 7 How do you access the internet while shopping on-line?
# 8 Which device do you use to access the online shopping?
# 9 What is the screen size of your mobile device?
# 10 What is the operating system (OS) of your device?
# 11 What browser do you run on your device to access the website?
# 12 Which channel did you follow to arrive at your favorite online store for the first time?
# 13 After first visit, how do you reach the online retail store?
# 14 How much time do you explore the e- retail store before making a purchase decision?
# 15 What is your preferred payment Option?
# 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?
# ...

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# the dataset has 269 rows and 71 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# this shows there is no any null values in any column. and also it shows the datatypes (object,int64)

# %% [markdown]
# since, the dataset has not any missing values, we are good to proceed to encoding the string data into int data.

# %%
data= pd.read_excel(r'C:\Users\JAYASHREE\Documents\customer_retention_coded.xlsx')

# %%
data.head(3)
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# 1                                           5
# 2                                           4
#
#    6 How many times you have made an online purchase in the past 1 year?  \
# 0                                                  4
# 1                                                  5
# ...

# %%
data.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.669145             2.959108
# std                 0.471398             1.066012
# min                 0.000000             1.000000
# 25%                 0.000000             2.000000
# 50%                 1.000000             3.000000
# 75%                 1.000000             4.000000
# max                 1.000000             5.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# ...

# %%
data.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                              -0.034449
# 4 What is the Pin Code of where you shop online...               0.260696
# 5 Since How Long You are Shopping Online ?                      -0.046005
# 6 How many times you have made an online purcha...               0.076121
# 7 How do you access the internet while shopping...              -0.200974
# 8 Which device do you use to access the online ...              -0.241847
# 9 What is the screen size of your mobile device...              -0.058760
# 10 What is the operating system (OS) of your de...              -0.038207
# 11 What browser do you run on your device to ac...              -0.116712
# 12 Which channel did you follow to arrive at yo...              -0.166694
# 13 After first visit, how do you reach the onli...               0.104118
# ...

# %%
data.plot.hist(by=None, bins=40, figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.catplot(x ="1Gender of respondent",
kind ="count", data = df)

# %%
sns.catplot(x = "5 Since How Long You are Shopping Online ?",
kind ="count", data = df)

# %%
sns.catplot(x = "6 How many times you have made an online purchase in the past 1 year?",
kind ="count", data = df)

# %%
sns.catplot(x = "7 How do you access the internet while shopping on-line?",
kind ="count", data = df)

# %%
sns.violinplot(x = "8 Which device do you use to access the online shopping?",
kind ="violin", data = data)
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?'>

# %%
sns.catplot(x = "18 The content on the website must be easy to read and understand",
kind ="count", data = df)

# %%
sns.catplot(x = "21 All relevant information on listed products must be stated clearly",
kind ="count", data = df)

# %%
sns.catplot(x = "22 Ease of navigation in website",
kind ="count", data = df)

# %%
sns.catplot(x = "23 Loading and processing speed",
kind ="count", data = df)

# %%
sns.catplot(x = "25 Convenient Payment methods",
kind ="count", data = df)

# %%
sns.catplot(x = "26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time",
kind ="count", data = df)

# %%
sns.catplot(x = "27 Empathy (readiness to assist with queries) towards the customers",
kind ="count", data = df)

# %%
sns.catplot(x = "28 Being able to guarantee the privacy of the customer",
kind ="count", data = df)

# %%
sns.catplot(x = "29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)",
kind ="count", data = df)

# %%
sns.catplot(x = "30 Online shopping gives monetary benefit and discounts",
kind ="count", data = df)

# %%
sns.catplot(x = "31 Enjoyment is derived from shopping online",
kind ="count", data = df)

# %%
sns.catplot(x = "32 Shopping online is convenient and flexible",
kind ="count", data = df)

# %%
sns.catplot(x = "33 Return and replacement policy of the e-tailer is important for purchase decision",
kind ="count", data = df)

# %%
sns.catplot(x = "34 Gaining access to loyalty programs is a benefit of shopping online",
kind ="count", data = df)

# %%
sns.catplot(x = "35 Displaying quality Information on the website improves satisfaction of customers",
kind ="count", data = df)

# %%
sns.catplot(x = "36 User derive satisfaction while shopping on a good quality website or application",
kind ="count", data = df)

# %%
sns.catplot(x = "37 Net Benefit derived from shopping online can lead to users satisfaction",
kind ="count", data = df)

# %%
sns.catplot(x = "38 User satisfaction cannot exist without trust",
kind ="count", data = df)

# %%
sns.catplot(x = "39 Offering a wide variety of listed product in several category",
kind ="count", data = df)

# %%
sns.catplot(x = "40 Provision of complete and relevant product information",
kind ="count", data = df)

# %%
sns.catplot(x = "41 Monetary savings",
kind ="count", data = df)

# %%
sns.catplot(x = "42 The Convenience of patronizing the online retailer",
kind ="count", data = df)

# %%
sns.catplot(x = "43 Shopping on the website gives you the sense of adventure",
kind ="count", data = df)

# %%
sns.catplot(x = "44 Shopping on your preferred e-tailer enhances your social status",
kind ="count", data = df)

# %%
sns.catplot(x = "45 You feel gratification shopping on your favorite e-tailer",
kind ="count", data = df)

# %%
sns.catplot(x = "46 Shopping on the website helps you fulfill certain roles",
kind ="count", data = df)

# %%
sns.catplot(x = "47 Getting value for money spent",
kind ="count", data = df)
